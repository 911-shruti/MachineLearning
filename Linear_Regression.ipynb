# %% [markdown]
# <a href="https://colab.research.google.com/github/911-shruti/LearningML/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv(r'https://drive.google.com/uc?export=download&id=1xxDtrZKfuWQfl-6KA9XEd_eatitNPnkB')

# %%
data
# Out:
#       bath  balcony   price  total_sqft_int  bhk  price_per_sqft  \
# 0      3.0      2.0  150.00          1672.0    3     8971.291866
# 1      3.0      3.0  149.00          1750.0    3     8514.285714
# 2      3.0      2.0  150.00          1750.0    3     8571.428571
# 3      2.0      2.0   40.00          1250.0    2     3200.000000
# 4      2.0      2.0   83.00          1200.0    2     6916.666667
# ...    ...      ...     ...             ...  ...             ...
# 7115   3.0      2.0  325.00          2900.0    3    11206.896552
# 7116   3.0      1.0   84.83          1780.0    3     4765.730337
# 7117   2.0      1.0   48.00           880.0    2     5454.545455
# 7118   2.0      1.0   55.00          1000.0    2     5500.000000
# 7119   2.0      1.0   78.00          1400.0    3     5571.428571
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                                 1                        0
# ...

# %%
data.isnull().sum()
# Out:
# bath                           0
# balcony                        0
# price                          0
# total_sqft_int                 0
# bhk                            0
#                               ..
# location_Hosur Road            0
# location_Horamavu Banaswadi    0
# location_Domlur                0
# location_Mahadevpura           0
# location_Tumkur Road           0
# Length: 108, dtype: int64

# %%
X=data.drop("price",axis=1)
y=data["price"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=51)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
X_train
# Out:
# array([[ 3.0245515 ,  0.55008644,  1.33396246, ..., -0.05630391,
#         -0.05630391, -0.05138463],
#        [-0.44274597, -2.0427027 , -0.60737352, ..., -0.05630391,
#         -0.05630391, -0.05138463],
#        [-0.44274597,  0.55008644, -0.36873754, ..., -0.05630391,
#         -0.05630391, -0.05138463],
#        ...,
#        [-0.44274597,  0.55008644, -0.49772996, ..., -0.05630391,
#         -0.05630391, -0.05138463],
#        [-0.44274597,  0.55008644, -0.62414253, ..., -0.05630391,
#         -0.05630391, -0.05138463],
#        [-0.44274597, -0.74630813, -0.6009239 , ..., -0.05630391,
#         -0.05630391, -0.05138463]])

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test)
# Out:
# array([ 76.90661876,  15.25005377, 113.6828165 , ...,  21.30296864,
#         71.43462962, 230.0414626 ])

# %%
y_test
# Out:
# 2435     80.00
# 3113     40.00
# 426     120.00
# 1124     79.00
# 1161     45.00
#          ...
# 2078     28.34
# 6855     84.00
# 4381     32.00
# 3862     63.00
# 43      180.00
# Name: price, Length: 1424, dtype: float64

# %%
lr.score(X_test,y_test)
# Out:
# 0.7903837092682255

# %%
from sklearn.linear_model import Lasso
ls=Lasso()
ls.fit(X_train,y_train)
# Out:
# Lasso()

# %%
ls.predict(X_test)
# Out:
# array([ 81.3103182 ,  17.58271013, 132.5549385 , ...,  19.98593615,
#         65.43686586, 224.75058885])

# %%
y_test
# Out:
# 2435     80.00
# 3113     40.00
# 426     120.00
# 1124     79.00
# 1161     45.00
#          ...
# 2078     28.34
# 6855     84.00
# 4381     32.00
# 3862     63.00
# 43      180.00
# Name: price, Length: 1424, dtype: float64

# %%
from sklearn.linear_model import Ridge
rd=Ridge()
rd.fit(X_train,y_train)
# Out:
# Ridge()

# %%
rd.predict(X_test)
# Out:
# array([ 76.92207759,  15.25945686, 113.70019676, ...,  21.29069552,
#         71.42880399, 230.01781562])

# %%
ls.score(X_test,y_test)
# Out:
# 0.8036373003525774
