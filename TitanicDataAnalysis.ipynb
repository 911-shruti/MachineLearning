# %% [markdown]
# <a href="https://colab.research.google.com/github/911-shruti/LearningML/blob/main/TitanicDataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/Titanic-Dataset.csv")

# %% [markdown]
# 1. how big is data

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# 2. How does the data look?

# %%
df.sample(5)
# gives random data objects
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 450          451         0       2                 West, Mr. Edwy Arthur
# 494          495         0       3            Stanley, Mr. Edward Roland
# 115          116         0       3                 Pekoniemi, Mr. Edvard
# 14            15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 674          675         0       2            Watson, Mr. Ennis Hastings
#
#         Sex   Age  SibSp  Parch             Ticket     Fare Cabin Embarked
# 450    male  36.0      1      2         C.A. 34651  27.7500   NaN        S
# 494    male  21.0      0      0          A/4 45380   8.0500   NaN        S
# 115    male  21.0      0      0  STON/O 2. 3101294   7.9250   NaN        S
# 14   female  14.0      0      0             350406   7.8542   NaN        S
# 674    male   NaN      0      0             239856   0.0000   NaN        S

# %% [markdown]
# 3. what is the data type of cols?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# 4. Are there any missing values?

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# 5. How does the data look mathematically?

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# 6. Are there Duplicate valiues?

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 7. How is correlation between cols?

# %%
df.corr(numeric_only = True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
df.corr(numeric_only = True)['Survived']
# survived ka all k sath correlation
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64

# %% [markdown]
# # Univariate Analysis:
# when we try to analyse a single attribute at a time is called Univariate Analysis.
#
# Data: 2 Types
#
# 1. Numerical( i.e: weight, height, age)
#
# 2. Categorical( i.e: nationality, collegename, etc.)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # 1. Categorical Data
#
# a. Countplot

# %%
# sns.countplot(x= df['Survived'])
df['Survived'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
df['Embarked'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked'>

# %% [markdown]
# b. Pie Chart

# %%
df['Pclass'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # 2. Numerical Data
#
# a. Histogram

# %%
plt.hist(df['Age'],bins=10)
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# b. Distplot: tells us data distribution
#
# the curve is KDE (Kernal Density Estimation)
#
#
# also called PDF(probability Distribution Function)
#
# we can also calculate skewnes with distplotoor with(df['Age'].skew) it its 0 then its perfectly skewed if positive then right skewed if negitive then  left skewed.

# %%
sns.distplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# c. Boxplot: gives us 5 number summery(median, %ile value)
#
# ![image.png](data:image/png;base64,...)

# %%
# for numerical data
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# for numerical values we can calculate minimum and maximum values calculaton

# %%
df['Age'].min(),df['Age'].max(),df['Age'].mean(),df['Age'].std()
# Out:
# (0.42, 80.0, np.float64(29.69911764705882), 14.526497332334044)
