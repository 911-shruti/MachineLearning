# %% [markdown]
# <a href="https://colab.research.google.com/github/911-shruti/MachineLearning/blob/main/MLBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()/df.shape[0]
# Out:
# sepal_length    0.0
# sepal_width     0.0
# petal_length    0.0
# petal_width     0.0
# species         0.0
# dtype: float64

# %%
df["species"].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df["species_mapped"]= df["species"].map({"setosa":1,"versicolor":2,"virginica":3})
df.drop("species",axis =1,inplace=True)

# %%
# df = df.rename(columns={"species_mapped":"species"})

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species_mapped
# 0             5.1          3.5           1.4          0.2               1
# 1             4.9          3.0           1.4          0.2               1
# 2             4.7          3.2           1.3          0.2               1
# 3             4.6          3.1           1.5          0.2               1
# 4             5.0          3.6           1.4          0.2               1
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3               3
# 146           6.3          2.5           5.0          1.9               3
# 147           6.5          3.0           5.2          2.0               3
# 148           6.2          3.4           5.4          2.3               3
# 149           5.9          3.0           5.1          1.8               3
#
# [150 rows x 5 columns]

# %%
df.rename(columns={"species_mapped":"species"},inplace=True)

# %%
df

# %%
X,Y=df.drop("species",axis=1),df["species"]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
model = LinearRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
Predict = model.predict(X_test)

# %%
X_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 73            6.1          2.8           4.7          1.2
# 18            5.7          3.8           1.7          0.3
# 118           7.7          2.6           6.9          2.3
# 78            6.0          2.9           4.5          1.5
# 76            6.8          2.8           4.8          1.4
# 31            5.4          3.4           1.5          0.4
# 64            5.6          2.9           3.6          1.3
# 141           6.9          3.1           5.1          2.3
# 68            6.2          2.2           4.5          1.5
# 82            5.8          2.7           3.9          1.2
# 110           6.5          3.2           5.1          2.0
# 12            4.8          3.0           1.4          0.1
# 36            5.5          3.5           1.3          0.2
# 9             4.9          3.1           1.5          0.1
# 19            5.1          3.8           1.5          0.3
# ...

# %%
print(Predict[0])
# Out:
# 2.230717148657721

# %%
print(y_test)
# Out:
# 73     2
# 18     1
# 118    3
# 78     2
# 76     2
# 31     1
# 64     2
# 141    3
# 68     2
# 82     2
# 110    3
# 12     1
# 36     1
# 9      1
# 19     1
# 56     2
# 104    3
# 69     2
# 55     2
# 132    3
# 29     1
# 127    3
# 26     1
# 128    3
# 131    3
# 145    3
# 108    3
# 143    3
# 45     1
# 30     1
# Name: species, dtype: int64

# %%
# SVM

# %%
from sklearn.svm import SVC

# %%
model2 = SVC(kernel = "rbf")

# %%
model2.fit(X_train,y_train)
# Out:
# SVC()

# %%
Predict2 = model2.predict(X_test)

# %%
print(Predict2)
# Out:
# [2 1 3 2 2 1 2 3 2 2 3 1 1 1 1 2 3 2 2 3 1 3 1 3 3 3 3 3 1 1]

# %%
print(y_test)
# Out:
# 73     2
# 18     1
# 118    3
# 78     2
# 76     2
# 31     1
# 64     2
# 141    3
# 68     2
# 82     2
# 110    3
# 12     1
# 36     1
# 9      1
# 19     1
# 56     2
# 104    3
# 69     2
# 55     2
# 132    3
# 29     1
# 127    3
# 26     1
# 128    3
# 131    3
# 145    3
# 108    3
# 143    3
# 45     1
# 30     1
# Name: species, dtype: int64

# %%
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model3 = DecisionTreeClassifier()

# %%
model3.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
Predict3 = model3.predict(X_test)

# %%
print(Predict3)
# Out:
# [2 1 3 2 2 1 2 3 2 2 3 1 1 1 1 2 3 2 2 3 1 3 1 3 3 3 3 3 1 1]

# %%
import matplotlib.pyplot as plt
from sklearn import tree

plt.figure(figsize=(15,10))

# Plot decision tree
tree.plot_tree(model3,
               filled=True,
               rounded=True,
               fontsize=12)

plt.title("Decision Tree for Iris Dataset")
plt.show()

# %%
# Clustring

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
model4 = kmeans.fit(X_train)


centers = kmeans.cluster_centers_
labels = kmeans.labels_

# %%
# Predict clusters for the entire dataset X
predicted_labels = kmeans.predict(X_train)

plt.scatter(X_train.iloc[:, 0], X_train.iloc[:, 1], c=predicted_labels, s=30, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, marker='X')
plt.title("K-Means Clustering with sklearn")
plt.show()

# %%
# Deep Learning basics

# %%
import tensorflow as tf

# %%
X_train.shape
# Out:
# (120, 4)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
nn_model = Sequential([
    Dense(16,input_dim = 4,activation = "relu"),
    Dense(16,activation = "relu"),
    Dense(8,activation = "relu"),
    Dense(1,activation = "relu")
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
nn_model.compile(optimizer="adam",loss = "mean_squared_error",metrics=["accuracy"])

# %%
nn_model.fit(X_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.3156 - loss: 0.0712 - recall: 1.0000
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3656 - loss: 0.0679 - recall: 1.0000
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3323 - loss: 0.0623 - recall: 1.0000
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3656 - loss: 0.0620 - recall: 1.0000
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3323 - loss: 0.0715 - recall: 1.0000
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3833 - loss: 0.0595 - recall: 1.0000
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3063 - loss: 0.0680 - recall: 1.0000
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3167 - loss: 0.0688 - recall: 1.0000
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3854 - loss: 0.0566 - recall: 1.0000
# Epoch 10/10
# ...
